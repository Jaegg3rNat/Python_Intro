# %% [markdown]
# # Item 1

# %%
import math as mt
import numpy as np

beta = 0.1
def gamma(beta): 
    """Função que toma beta como argumento e retorna gamma"""
    return  1/(mt.sqrt(1- beta**2))

print(gamma(beta))
# Out:
# 1.005037815259212

# %% [markdown]
# # Item 2

# %%
import math as mt
import numpy as np

beta = np.array([0.1, 0.2])
def gamma(beta):   
    """Função que toma beta como argumento e retorna gamma"""
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

print(gamma(beta))
# Out:
# [1.005037815259212, 1.0206207261596576]

# %% [markdown]
# # Item 3,4

# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


#vetor de beta
beta = np.arange(0,0.995,0.01)

#gamma calculado a partir de Beta
def gamma(beta):   
    """Função que toma beta como argumento e retorna gamma"""
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

#print(gamma(beta))

#print(gamma(beta)*beta)


x = beta


fig, ax = plt.subplots(1,2,figsize=(9, 4.5), tight_layout=True )
ax[0].set_xlabel('β')
ax[0].set_ylabel('γ')
ax[0].plot(x , gamma(beta), 'r-')

ax[1].set_xlabel('β')
ax[1].set_ylabel('γβ')
ax[1].plot(x , beta*gamma(beta),'b-')

#plot = plt.plot(x, gamma3(beta), 'r--', x, gamma3(beta)*beta, 'b-')  comparar os plots
fig1, ax1 = plt.subplots(figsize=(9, 4.5), tight_layout=True )
ax1.plot(x, gamma(beta), 'r--', x, gamma(beta)*beta, 'b-')
ax1.legend(['γ', 'γβ'])
ax1.set_xlabel('β')
ax1.grid()
ax1.fill_between(x,gamma(beta),gamma(beta)*beta, alpha= 0.2)

# %% [markdown]
# # Item 5,6,7

# %%
GB = np.linspace(0.1,100,1000)

mec = 0.5110
I = 1
def ln_argument2(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/I
        lista2.append(novo_elemento2)
    return lista2


fig, ax = plt.subplots(1,2,figsize=(9, 4.5), tight_layout=True )
ax[0].set_xlabel('beta')
ax[0].set_ylabel('gamma')
ax[0].plot(GB , ln_argument2(GB), 'r-')
ax[1].semilogy(GB , ln_argument2(GB), 'b-')
ax[0].grid()
ax[1].grid()

# %% [markdown]
# # Item 8

# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
c = 3*10**8
v = np.linspace(0.0001*c,0.99995*c,10000)
beta = v/c # define o vetor beta
I=10e-06
#define vetor gamma
def gamma(beta):    
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

#define vetor gamma*beta

GB = gamma(beta)*beta

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/322**2
        lista2.append(novo_elemento2)
    return lista2

#vetor beta**2

Beta = beta*beta
#print(Beta)

print(np.log(ln_argument3(GB))-Beta)
fig, ax = plt.subplots(1,1,figsize=(9, 4.5), tight_layout=True )
ax.set_xlabel('beta')
ax.set_ylabel('gamma')
ax.plot(GB , np.log(ln_argument3(GB))-Beta, 'r-')
# Out:
# [-29.94802234 -28.56177799 -27.75086444 ...  -4.92627426  -4.41550522
#   -3.31697623]

# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
I =3.55

#define vetor gamma*beta

GB = np.linspace(0.1,100,100)

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/I
        lista2.append(novo_elemento2)
    return lista2

#vetor beta**2

Beta = 1- 1/(GB**2 + 1)
#print(Beta)


fig, ax = plt.subplots(1,1,figsize=(9, 4.5), tight_layout=True )
ax.set_xlabel('beta')
ax.set_ylabel('gamma')
ax.plot(GB , np.log(ln_argument3(GB))-Beta, 'r-')

# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
c = 3*10**8
v = np.linspace(0.0001*c,0.99995*c,10000)
beta = v/c # define o vetor beta
I =10e-06
#define vetor gamma
def gamma(beta):    
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

#define vetor gamma*beta

GB = gamma(beta)*beta

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/I
        lista2.append(novo_elemento2)
    return lista2

#vetor beta**2

Beta = beta*beta
#print(Beta)




#define vetor gamma*beta

GB2 = np.linspace(0.1,100,100)

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB2):
    lista3 = []
    for (i, valor) in enumerate(GB2):
        novo_elemento3 = (2*mec*(valor)**2)/I
        lista3.append(novo_elemento3)
    return lista3

#vetor beta**2

Beta2 = 1- 1/(GB2**2 + 1)
#print(Beta)





fig, ax = plt.subplots(1,1, figsize = (9,4.5), tight_layout = True)
ax.plot(GB , np.log(ln_argument3(GB))-Beta, 'r-',GB2 , np.log(ln_argument3(GB2))-Beta2, 'b-')
ax.set_xlim(-1, 10)
ax.set_ylim(-10, 30)
# Out:
# (-10.0, 30.0)

# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
c = 3*10**8
v = np.linspace(0.001*c,0.999995*c,10000)
beta = v/c # define o vetor beta
I = 10e-06
K = 0.307
z = -1
Z = 29
A = 63.546
ZA = Z/A
rho = 8.96
mec = 0.5110
#define vetor gamma
def gamma(beta):    
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

#define vetor gamma*beta

GB = gamma(beta)*beta

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/I
        lista2.append(novo_elemento2)
    return lista2

#vetor beta**2

Beta = beta*beta
#print(Beta)

Energy=K*(z**2)*rho*(ZA)*(1/Beta)*(np.log(ln_argument3(GB))-Beta)

fig, ax = plt.subplots(1,1,figsize=(9, 6), tight_layout=True )
ax.set_ylabel('Energy')
ax.set_xlabel('gamma*beta')
ax.plot(GB , Energy, 'r-')
ax.set_xlim(0.1, 20)
ax.set_ylim(-1, 100)

A = 1.069/rho
B = 184.9/rho
N = 1200
def func(x):
    return (K*(z**2)*rho*(ZA)*(1/Beta)*(np.log(ln_argument3(GB))-Beta))  

#definindo o trapézio
def trapezoid(A,B,N): 
    h = (B-A)/(N-1) 
    soma = (func(A) + func(B))/2  
    for i in range(1,N-1):  #repetição para somar os trapézios
        soma += func(A+ i*h)
    return h*soma

print(trapezoid(A,B,N-1))
print('A perda de Energia Média do muon foi de:',np.max(trapezoid(A,B,N-1))- np.min(trapezoid(A,B,N-1)),'eV')
# Plot do grafico para o f(x)
#x = np.linspace(A,B,1000)



fig, ax = plt.subplots(1,1,figsize=(9, 6), tight_layout=True )
ax.set_ylabel('Energy')
ax.set_xlabel('gamma*beta')
ax.plot(GB , -trapezoid(A,B,N-1), 'r-')
#ax.set_xlim(0.1, 50)
#ax.set_ylim(-1, 6)
print(np.sum(trapezoid(A,B,N-1)))
# Out:
# [-5.87433355e+07 -4.45016091e+07 -3.42878489e+07 ...  4.72417915e+02
#   4.89556886e+02  5.67848996e+02]
# A perda de Energia Média do muon foi de: 59711557.098421544 eV
# -106556663.08231166

# %%
# Resolva Integral de Qq função usando o método do Trapézio/ Plote o Gráfico da Função
import numpy as np
import matplotlib.pyplot as plt
import math as mt
# %matplotlib inline
c = 3*10**8
v = np.linspace(0.001*c,0.9999995*c,10000)
beta = v/c # define o vetor beta
I = 10e-06
K = 0.307
z = -1
Z = 29
A = 63.546
ZA = Z/A
rho = 8.96
mec = 0.5110
#define vetor gamma
def gamma(beta):    
    nova_lista = []
    for (i, valor) in enumerate(beta):
        novo_elemento = 1/(mt.sqrt(1- valor**2))
        nova_lista.append(novo_elemento)
    return nova_lista

#define vetor gamma*beta

GB = gamma(beta)*beta

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB):
    lista2 = []
    for (i, valor) in enumerate(GB):
        novo_elemento2 = (2*mec*(valor)**2)/I
        lista2.append(novo_elemento2)
    return lista2

#vetor beta**2

Beta = beta*beta
#print(Beta)

Energy=K*(z**2)*rho*(ZA)*(1/Beta)*(np.log(ln_argument3(GB))-Beta)

fig, ax = plt.subplots(1,1,figsize=(9, 6), tight_layout=True )
ax.set_xlabel('Energy')
ax.set_ylabel('gamma*beta')
ax.plot(GB , Energy, 'r-')
ax.set_xlim(0.1, 20)
ax.set_ylim(-1, 100)

A = 0.1
B = 3.27
N = 10000   #número de trapézios


#defina aqui a função a ser integrada
def func(GB):
    return (K*(z**2)*rho*(ZA)*(1/Beta)*(np.log(ln_argument3(GB))-Beta))  

#definindo o trapézio
def trapezoid(A,B,N): 
    h = (B-A)/(N-1) 
    soma = (func(A) + func(B))/2  
    for i in range(1,N-1):  #repetição para somar os trapézios
        soma += func(A+ i*h)
    return h*soma

print(trapezoid(A,B,N-1))

# Plot do grafico para o f(x)
x = np.linspace(A,B,1000)
fig, ax = plt.subplots()
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.plot(GB , func(GB))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5d2d95d9a21b> in <module>
#      66     return h*soma
#      67
# ---> 68 print(trapezoid(A,B,N-1))
#      69
#      70 # Plot do grafico para o f(x)
#
# <ipython-input-6-5d2d95d9a21b> in trapezoid(A, B, N)
#      61 def trapezoid(A,B,N):
#      62     h = (B-A)/(N-1)
# ---> 63     soma = (func(A) + func(B))/2
#      64     for i in range(1,N-1):  #repetição para somar os trapézios
#      65         soma += func(A+ i*h)
#
# <ipython-input-6-5d2d95d9a21b> in func(GB)
#      56 #defina aqui a função a ser integrada
#      57 def func(GB):
# ---> 58     return (K*(z**2)*rho*(ZA)*(1/Beta)*(np.log(ln_argument3(GB))-Beta))
#      59
#      60 #definindo o trapézio
#
# <ipython-input-6-5d2d95d9a21b> in ln_argument3(GB)
#      30 def ln_argument3(GB):
#      31     lista2 = []
# ---> 32     for (i, valor) in enumerate(GB):
#      33         novo_elemento2 = (2*mec*(valor)**2)/I
#      34         lista2.append(novo_elemento2)
#
# TypeError: 'float' object is not iterable

# %%
#define vetor gamma*beta

GB2 = np.linspace(0.001,100,100)

#função que cria o argumento do Ln baseado em gamma*beta
def ln_argument3(GB2):
    lista3 = []
    for (i, valor) in enumerate(GB2):
        novo_elemento3 = (2*mec*(valor)**2)/I
        lista3.append(novo_elemento3)
    return lista3

#vetor beta**2

Beta2 = 1- 1/(GB2**2 + 1)
#print(Beta)
A = 1.069/rho
B = 184.9/rho
N = 1200
def func(x):
    return (K*(z**2)*rho*(ZA)*(1/Beta2)*(np.log(ln_argument3(GB2))-Beta2))  

#definindo o trapézio
def trapezoid(A,B,N): 
    h = (B-A)/(N-1) 
    soma = (func(A) + func(B))/2  
    for i in range(1,N-1):  #repetição para somar os trapézios
        soma += func(A+ i*h)
    return h*soma

print(trapezoid(A,B,N-1))
# Plot do grafico para o f(x)
#x = np.linspace(A,B,1000)
fig, ax = plt.subplots()
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
ax.plot(np.log(GB2) , func(GB2))
# Out:
# [-5.87434201e+07  5.63045908e+02  3.89165529e+02  3.66996733e+02
#   3.65856986e+02  3.69666665e+02  3.74756289e+02  3.80039242e+02
#   3.85157560e+02  3.89996966e+02  3.94532651e+02  3.98773646e+02
#   4.02741078e+02  4.06459289e+02  4.09952207e+02  4.13241939e+02
#   4.16348352e+02  4.19289061e+02  4.22079600e+02  4.24733638e+02
#   4.27263218e+02  4.29678960e+02  4.31990262e+02  4.34205459e+02
#   4.36331969e+02  4.38376416e+02  4.40344731e+02  4.42242245e+02
#   4.44073763e+02  4.45843627e+02  4.47555776e+02  4.49213789e+02
#   4.50820928e+02  4.52380176e+02  4.53894262e+02  4.55365695e+02
#   4.56796782e+02  4.58189649e+02  4.59546262e+02  4.60868441e+02
#   4.62157871e+02  4.63416122e+02  4.64644651e+02  4.65844818e+02
#   4.67017892e+02  4.68165059e+02  4.69287431e+02  4.70386048e+02
#   4.71461890e+02  4.72515873e+02  4.73548863e+02  4.74561676e+02
#   4.75555079e+02  4.76529798e+02  4.77486519e+02  4.78425891e+02
#   4.79348529e+02  4.80255016e+02  4.81145905e+02  4.82021721e+02
#   4.82882963e+02  4.83730107e+02  4.84563604e+02  4.85383885e+02
#   4.86191362e+02  4.86986426e+02  4.87769452e+02  4.88540798e+02
#   4.89300806e+02  4.90049802e+02  4.90788101e+02  4.91516004e+02
#   4.92233796e+02  4.92941756e+02  4.93640147e+02  4.94329225e+02
#   4.95009233e+02  4.95680407e+02  4.96342973e+02  4.96997147e+02
#   4.97643140e+02  4.98281153e+02  4.98911381e+02  4.99534010e+02
#   5.00149221e+02  5.00757188e+02  5.01358081e+02  5.01952060e+02
#   5.02539283e+02  5.03119902e+02  5.03694063e+02  5.04261908e+02
#   5.04823575e+02  5.05379195e+02  5.05928898e+02  5.06472807e+02
#   5.07011045e+02  5.07543727e+02  5.08070966e+02  5.08592873e+02]
